# %% [markdown]
# # Class in Object Oriented Programing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a= 22
print(type(a))
# Out:
# <class 'int'>

# %%
b = 21.0
print(type(b))
# Out:
# <class 'float'>

# %%
c = False
print(type(c))
# Out:
# <class 'bool'>

# %%
d="ETLHIVE"
print(type(d))
# Out:
# <class 'str'>

# %%
e = [1,2,3,4,5]
print(type(e))
# Out:
# <class 'list'>

# %%
g={
    "Roll_no" : [1,2,3],
    "Name" : ["Sid","Raj","Jay"],
    "Marks" : [50,65,48]

}
print(type(g))
# Out:
# <class 'dict'>

# %%
import pandas as pd

# %%
df= pd.DataFrame(g)
df
# Out:
#    Roll_no Name  Marks
# 0        1  Sid     50
# 1        2  Raj     65
# 2        3  Jay     48

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Attributes of Class Dataframe

# %%
df.columns
# Out:
# Index(['Roll_no', 'Name', 'Marks'], dtype='object')

# %%
list(df.index)
# Out:
# [0, 1, 2]

# %%
df.shape
# Out:
# (3, 3)

# %%
df.dtypes
# Out:
# Roll_no     int64
# Name       object
# Marks       int64
# dtype: object

# %% [markdown]
# ### Methods (Functions) of class dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_no  3 non-null      int64
#  1   Name     3 non-null      object
#  2   Marks    3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.sort_values(by="Marks",ascending=False)
# Out:
#    Roll_no Name  Marks
# 1        2  Raj     65
# 0        1  Sid     50
# 2        3  Jay     48

# %%
df.isna().sum()
# Out:
# Roll_no    0
# Name       0
# Marks      0
# dtype: int64

# %%
df.agg({"Marks":"mean"})
# Out:
# Marks    54.333333
# dtype: float64

# %% [markdown]
# ### creating a user defined class

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:


    # First function is a constructor function
    def __init__(self,name,age,gender,occupation) :
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation

    # Extra function for class
    def talk(self):
        print(f"Hi there my name is {self.name}")
        print(f"I am Currently {self.age} yrs old")
        print(f"i am {self.gender}")
        print(f"i work as a  {self.occupation}")

# %%
p1= Person(name="sid", age=22 , gender= "male",occupation="gamer")

# %%
p1

# %%
print(type(p1))
# Out:
# <class '__main__.Person'>

# %% [markdown]
# ### __main__ refers yo the current file i am working on

# %% [markdown]
# attributes of class person

# %%
p1.name
# Out:
# 'sid'

# %%
p1.age
# Out:
# 22

# %%
p1.gender
# Out:
# 'male'

# %%
p1.occupation
# Out:
# 'gamer'

# %% [markdown]
# ## methods talk for class person

# %%
p1.talk()
# Out:
# Hi there my name is sid
# I am Currently 22 yrs old
# i am male
# i work as a  gamer

# %%
p2=Person('jaya',22,"female","coder")
type(p2)
# Out:
# __main__.Person

# %%
p2.age
# Out:
# 22

# %%
p2.name
# Out:
# 'jay'

# %%
p2.occupation
# Out:
# 'coder'

# %% [markdown]
# ## Modifying the age

# %%
p2.age=29

# %%
p2.age
# Out:
# 29

# %%
p2.talk()
# Out:
# Hi there my name is jaya
# I am Currently 22 yrs old
# i am female
# i work as a  coder

# %% [markdown]
# ### Some Disadvantage of creating classes directly

# %%
p3=Person(name=22,age="rahul",gender="engg",occupation="male")

# %%
p3.age
# Out:
# 'rahul'

# %%
p3.gender
# Out:
# 'engg'

# %%
p3.talk()
# Out:
# Hi there my name is 22
# I am Currently rahul yrs old
# i am engg
# i work as a  male

# %% [markdown]
# ### invalid inputs work fine by creating class directly

# %% [markdown]
# ### Dataclasses in python
